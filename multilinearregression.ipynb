# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_index=pd.read_csv('economic_index.csv')
df_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
#drop unneccessary columns
df_index.drop(columns=["Unnamed: 0","year","month"],axis=1,inplace=True)

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
##to check null values and place them with true if null, and finally counting all the
# true values to find the number of null values
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
##visualization
import seaborn as sns
sns.pairplot(df_index)

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
plt.scatter(df_index['interest_rate'],df_index['unemployment_rate'],color='red')
plt.xlabel('Interest rate')
plt.ylabel('unemployment rate')
# Out:
# Text(0, 0.5, 'unemployment rate')

# %%
##independent and dependent features
X=df_index[['interest_rate','unemployment_rate']] 
y=df_index['index_price'] 
# we can also write it as X=df_index.iloc[:,:-1]<-for independent
# y=df_index.iloc[:,-1]<-for dependent variable

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25, random_state=42)

# %%
##new type of plot from seaborn -->REG PLOT
import seaborn as sns

# %%
sns.regplot(x=df_index['interest_rate'],y=df_index['index_price'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='index_price'>

# %%
sns.regplot(x=df_index['interest_rate'],y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %%
sns.regplot(x=df_index['index_price'],y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='index_price', ylabel='unemployment_rate'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)
X_train
# Out:
# array([[-0.90115511,  0.37908503],
#        [ 1.31077107, -1.48187786],
#        [-0.90115511,  1.30956648],
#        [ 1.31077107, -0.55139641],
#        [ 1.31077107, -1.48187786],
#        [-0.16384638,  0.68924552],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -1.48187786],
#        [ 1.31077107, -1.17171738],
#        [-0.90115511,  1.30956648],
#        [-0.90115511,  0.999406  ],
#        [-0.90115511,  0.37908503],
#        [-0.90115511,  0.999406  ],
#        [ 0.57346234, -0.8615569 ],
#        [-0.16384638, -0.24123593],
#        [-0.90115511,  0.06892455],
#        [-0.90115511,  0.999406  ],
#        [ 1.31077107, -0.8615569 ]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
##cross validation -->VERY IMPORTANT
from sklearn.model_selection import cross_val_score

# %%
validation_score=cross_val_score(regression,X_train, y_train,scoring='neg_mean_squared_error',cv=3)

# %%
np.mean(validation_score)
# Out:
# np.float64(-5914.828180162386)

# %%
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([1180.7466813 ,  802.74279699, 1379.83457045,  838.52599602,
#         973.85313963, 1144.96348227])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test, y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 8108.567426306604
# 73.80444932337097
# 90.04758423359621

# %%
#R SQUARED VALUE
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7591371539010257

# %%
##ADJUSTED R SQUARED VALUE
1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.5985619231683761

# %% [markdown]
# ##ASSUMPTIONS
# 1. IF THERE EXISTS A LINEAR RELATON BETWEEN Y_TEST AND YPRED THEN ITS A GOOD THING

# %%
plt.scatter(y_test,y_pred)

# %%
residuals=y_test-y_pred
print(residuals)
# Out:
# 8     -21.746681
# 16    168.257203
# 0      84.165430
# 18     45.474004
# 11    101.146860
# 9      22.036518
# Name: index_price, dtype: float64

# %%
##plot this residuals
sns.displot(residuals,kind='kde')#<--kde plot made

# %%
##scatter plot with respect to prediction and residuals
plt.scatter(y_pred,residuals)

# %%
##using OLS
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,X_train).fit()

# %%
prediction=model.predict(X_test)
print(prediction)
# Out:
# [ 127.30223686 -250.70164745  326.390126   -214.91844842  -79.59130481
#    91.51903783]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:            index_price   R-squared (uncentered):                   0.035
# Model:                            OLS   Adj. R-squared (uncentered):             -0.086
# Method:                 Least Squares   F-statistic:                             0.2880
# Date:                Wed, 23 Oct 2024   Prob (F-statistic):                       0.754
# Time:                        16:20:49   Log-Likelihood:                         -150.85
# No. Observations:                  18   AIC:                                      305.7
# Df Residuals:                      16   BIC:                                      307.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
